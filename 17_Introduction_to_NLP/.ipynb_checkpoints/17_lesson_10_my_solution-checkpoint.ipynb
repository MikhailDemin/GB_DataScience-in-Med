# %% [markdown]
# # Урок 10. Машинный перевод. Модель seq2seq и механизм внимания
# ## Домашнее задание.

# %% [markdown]
# Разобраться с моделькой перевода (без механизма внимания) как она устроена, запустить для перевода с русского на английский (при желании можно взять другие пары языков)
#  - Написать и обучить модель перевода с русского на английский на библиотеке `pytorch`.
#  - Добавить в неё механизм внимания, так как это сложнее и интереснее,
#  - а также рекуррентную сеть энкодера сделать двунаправленной.

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %%
# !wget http://www.manythings.org/anki/rus-eng.zip
# !unzip rus-eng.zip
# Out:
# --2023-02-20 10:59:06--  http://www.manythings.org/anki/rus-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15011848 (14M) [application/zip]
# Saving to: ‘rus-eng.zip’
#
# rus-eng.zip         100%[===================>]  14.32M  43.4MB/s    in 0.3s
#
# 2023-02-20 10:59:07 (43.4 MB/s) - ‘rus-eng.zip’ saved [15011848/15011848]
#
# Archive:  rus-eng.zip
#   inflating: rus.txt
#   inflating: _about.txt

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  w = '<start> ' + w + ' <end>'
  return w

# %%
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
en, rus = create_dataset('/content/rus.txt', None)

# %%
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset('/content/rus.txt', num_examples)

max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
#steps_per_epoch = int((len(input_tensor_train)//BATCH_SIZE)/13)
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

example_input_batch, example_target_batch = next(iter(dataset))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

  def call(self, x, hidden):

    x = self.embedding(x)

    output, state = self.gru(x, initial_state=hidden)

    output = tf.reshape(output, (-1, output.shape[2]))

    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
checkpoint_prefix = os.path.join('/content/', "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0
    
    with tf.GradientTape() as tape:
        enc_hidden = encoder(inp, enc_hidden)
        
        dec_hidden = enc_hidden

        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

        for t in range(1, targ.shape[1]):
            predictions, dec_hidden = decoder(dec_input, dec_hidden)
            loss += loss_function(targ[:, t], predictions)
            dec_input = tf.expand_dims(targ[:, t], 1)

        batch_loss = (loss / int(targ.shape[1]))

        variables = encoder.trainable_variables + decoder.trainable_variables

        gradients = tape.gradient(loss, variables)

        optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1, total_loss / steps_per_epoch))
  print('Time per epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.5638
# Epoch 1 Batch 100 Loss 2.1312
# Epoch 1 Batch 200 Loss 1.8090
# Epoch 1 Batch 300 Loss 1.6443
# Epoch 1 Batch 400 Loss 1.5977
# Epoch 1 Batch 500 Loss 1.4661
# Epoch 1 Batch 600 Loss 1.2933
# Epoch 1 Batch 700 Loss 1.2116
# Epoch 1 Batch 800 Loss 1.1223
# Epoch 1 Batch 900 Loss 1.1799
# Epoch 1 Batch 1000 Loss 1.0309
# Epoch 1 Batch 1100 Loss 0.8658
# Epoch 1 Batch 1200 Loss 1.0020
# Epoch 1 Loss 1.4003
# Time per epoch 75.85141444206238 sec
#
# Epoch 2 Batch 0 Loss 0.8663
# Epoch 2 Batch 100 Loss 0.8155
# Epoch 2 Batch 200 Loss 0.7592
# Epoch 2 Batch 300 Loss 0.7685
# Epoch 2 Batch 400 Loss 0.6978
# Epoch 2 Batch 500 Loss 0.7584
# Epoch 2 Batch 600 Loss 0.6019
# Epoch 2 Batch 700 Loss 0.6675
# Epoch 2 Batch 800 Loss 0.5342
# Epoch 2 Batch 900 Loss 0.6302
# Epoch 2 Batch 1000 Loss 0.5391
# Epoch 2 Batch 1100 Loss 0.6222
# Epoch 2 Batch 1200 Loss 0.5993
# Epoch 2 Loss 0.6646
# Time per epoch 55.052490234375 sec
#
# Epoch 3 Batch 0 Loss 0.3872
# Epoch 3 Batch 100 Loss 0.3891
# Epoch 3 Batch 200 Loss 0.3173
# Epoch 3 Batch 300 Loss 0.3921
# Epoch 3 Batch 400 Loss 0.3385
# Epoch 3 Batch 500 Loss 0.3530
# Epoch 3 Batch 600 Loss 0.3066
# Epoch 3 Batch 700 Loss 0.4733
# Epoch 3 Batch 800 Loss 0.3837
# Epoch 3 Batch 900 Loss 0.3616
# Epoch 3 Batch 1000 Loss 0.2864
# Epoch 3 Batch 1100 Loss 0.2835
# Epoch 3 Batch 1200 Loss 0.3428
# Epoch 3 Loss 0.3522
# Time per epoch 53.22130751609802 sec
#
# Epoch 4 Batch 0 Loss 0.1665
# Epoch 4 Batch 100 Loss 0.2493
# Epoch 4 Batch 200 Loss 0.2105
# Epoch 4 Batch 300 Loss 0.2187
# Epoch 4 Batch 400 Loss 0.1772
# Epoch 4 Batch 500 Loss 0.2403
# Epoch 4 Batch 600 Loss 0.2222
# Epoch 4 Batch 700 Loss 0.1604
# Epoch 4 Batch 800 Loss 0.1712
# Epoch 4 Batch 900 Loss 0.1856
# Epoch 4 Batch 1000 Loss 0.3168
# Epoch 4 Batch 1100 Loss 0.2032
# Epoch 4 Batch 1200 Loss 0.1568
# Epoch 4 Loss 0.2106
# Time per epoch 54.27447175979614 sec
#
# Epoch 5 Batch 0 Loss 0.1062
# Epoch 5 Batch 100 Loss 0.1492
# Epoch 5 Batch 200 Loss 0.1281
# Epoch 5 Batch 300 Loss 0.0971
# Epoch 5 Batch 400 Loss 0.0944
# Epoch 5 Batch 500 Loss 0.1511
# Epoch 5 Batch 600 Loss 0.1212
# Epoch 5 Batch 700 Loss 0.1187
# Epoch 5 Batch 800 Loss 0.1180
# Epoch 5 Batch 900 Loss 0.2178
# Epoch 5 Batch 1000 Loss 0.2088
# Epoch 5 Batch 1100 Loss 0.1363
# Epoch 5 Batch 1200 Loss 0.1871
# Epoch 5 Loss 0.1447
# Time per epoch 53.212151765823364 sec
#
# Epoch 6 Batch 0 Loss 0.0938
# Epoch 6 Batch 100 Loss 0.0684
# Epoch 6 Batch 200 Loss 0.0899
# Epoch 6 Batch 300 Loss 0.0826
# Epoch 6 Batch 400 Loss 0.0948
# Epoch 6 Batch 500 Loss 0.0869
# Epoch 6 Batch 600 Loss 0.1036
# Epoch 6 Batch 700 Loss 0.1298
# Epoch 6 Batch 800 Loss 0.1182
# Epoch 6 Batch 900 Loss 0.0846
# Epoch 6 Batch 1000 Loss 0.0610
# Epoch 6 Batch 1100 Loss 0.1380
# Epoch 6 Batch 1200 Loss 0.1471
# Epoch 6 Loss 0.1138
# Time per epoch 54.56547832489014 sec
#
# Epoch 7 Batch 0 Loss 0.0816
# Epoch 7 Batch 100 Loss 0.0638
# Epoch 7 Batch 200 Loss 0.1090
# Epoch 7 Batch 300 Loss 0.1086
# Epoch 7 Batch 400 Loss 0.1024
# Epoch 7 Batch 500 Loss 0.0996
# Epoch 7 Batch 600 Loss 0.0994
# Epoch 7 Batch 700 Loss 0.0914
# Epoch 7 Batch 800 Loss 0.1329
# Epoch 7 Batch 900 Loss 0.1294
# Epoch 7 Batch 1000 Loss 0.1352
# Epoch 7 Batch 1100 Loss 0.0820
# Epoch 7 Batch 1200 Loss 0.1260
# Epoch 7 Loss 0.0973
# Time per epoch 53.698845863342285 sec
#
# Epoch 8 Batch 0 Loss 0.0746
# Epoch 8 Batch 100 Loss 0.0778
# Epoch 8 Batch 200 Loss 0.0900
# Epoch 8 Batch 300 Loss 0.0651
# Epoch 8 Batch 400 Loss 0.0796
# Epoch 8 Batch 500 Loss 0.0878
# Epoch 8 Batch 600 Loss 0.0966
# Epoch 8 Batch 700 Loss 0.0899
# Epoch 8 Batch 800 Loss 0.0800
# Epoch 8 Batch 900 Loss 0.1116
# Epoch 8 Batch 1000 Loss 0.1353
# Epoch 8 Batch 1100 Loss 0.0695
# Epoch 8 Batch 1200 Loss 0.1353
# Epoch 8 Loss 0.0885
# Time per epoch 54.06794190406799 sec
#
# Epoch 9 Batch 0 Loss 0.0590
# Epoch 9 Batch 100 Loss 0.0404
# Epoch 9 Batch 200 Loss 0.0851
# Epoch 9 Batch 300 Loss 0.0800
# Epoch 9 Batch 400 Loss 0.0871
# Epoch 9 Batch 500 Loss 0.1078
# Epoch 9 Batch 600 Loss 0.0877
# Epoch 9 Batch 700 Loss 0.1127
# Epoch 9 Batch 800 Loss 0.0851
# Epoch 9 Batch 900 Loss 0.0510
# Epoch 9 Batch 1000 Loss 0.0780
# Epoch 9 Batch 1100 Loss 0.0530
# Epoch 9 Batch 1200 Loss 0.0891
# Epoch 9 Loss 0.0825
# Time per epoch 53.56250333786011 sec
#
# Epoch 10 Batch 0 Loss 0.0940
# Epoch 10 Batch 100 Loss 0.0498
# Epoch 10 Batch 200 Loss 0.0992
# Epoch 10 Batch 300 Loss 0.0419
# Epoch 10 Batch 400 Loss 0.1209
# Epoch 10 Batch 500 Loss 0.0701
# Epoch 10 Batch 600 Loss 0.0608
# Epoch 10 Batch 700 Loss 0.0943
# Epoch 10 Batch 800 Loss 0.0534
# Epoch 10 Batch 900 Loss 0.0724
# Epoch 10 Batch 1000 Loss 0.0572
# Epoch 10 Batch 1100 Loss 0.0910
# Epoch 10 Batch 1200 Loss 0.1036
# Epoch 10 Loss 0.0790
# Time per epoch 53.83091330528259 sec
#
# Epoch 11 Batch 0 Loss 0.0623
# Epoch 11 Batch 100 Loss 0.0647
# Epoch 11 Batch 200 Loss 0.0792
# Epoch 11 Batch 300 Loss 0.0949
# Epoch 11 Batch 400 Loss 0.0620
# Epoch 11 Batch 500 Loss 0.0691
# Epoch 11 Batch 600 Loss 0.0758
# Epoch 11 Batch 700 Loss 0.1102
# Epoch 11 Batch 800 Loss 0.0662
# Epoch 11 Batch 900 Loss 0.0637
# Epoch 11 Batch 1000 Loss 0.0774
# Epoch 11 Batch 1100 Loss 0.0705
# Epoch 11 Batch 1200 Loss 0.0797
# Epoch 11 Loss 0.0759
# Time per epoch 53.34816384315491 sec
#
# Epoch 12 Batch 0 Loss 0.0421
# Epoch 12 Batch 100 Loss 0.0914
# Epoch 12 Batch 200 Loss 0.0564
# Epoch 12 Batch 300 Loss 0.0455
# Epoch 12 Batch 400 Loss 0.0572
# Epoch 12 Batch 500 Loss 0.0382
# Epoch 12 Batch 600 Loss 0.0737
# Epoch 12 Batch 700 Loss 0.1438
# Epoch 12 Batch 800 Loss 0.0649
# Epoch 12 Batch 900 Loss 0.0433
# Epoch 12 Batch 1000 Loss 0.0940
# Epoch 12 Batch 1100 Loss 0.0622
# Epoch 12 Batch 1200 Loss 0.1246
# Epoch 12 Loss 0.0730
# Time per epoch 54.02545881271362 sec
#
# Epoch 13 Batch 0 Loss 0.0605
# Epoch 13 Batch 100 Loss 0.0277
# Epoch 13 Batch 200 Loss 0.0741
# Epoch 13 Batch 300 Loss 0.0467
# Epoch 13 Batch 400 Loss 0.0642
# Epoch 13 Batch 500 Loss 0.0815
# Epoch 13 Batch 600 Loss 0.0777
# Epoch 13 Batch 700 Loss 0.0724
# Epoch 13 Batch 800 Loss 0.0668
# Epoch 13 Batch 900 Loss 0.0822
# Epoch 13 Batch 1000 Loss 0.0508
# Epoch 13 Batch 1100 Loss 0.0790
# Epoch 13 Batch 1200 Loss 0.0861
# Epoch 13 Loss 0.0707
# Time per epoch 53.19157934188843 sec
#
# Epoch 14 Batch 0 Loss 0.0241
# Epoch 14 Batch 100 Loss 0.0304
# Epoch 14 Batch 200 Loss 0.0597
# Epoch 14 Batch 300 Loss 0.0507
# Epoch 14 Batch 400 Loss 0.0444
# Epoch 14 Batch 500 Loss 0.0801
# Epoch 14 Batch 600 Loss 0.0530
# Epoch 14 Batch 700 Loss 0.0753
# Epoch 14 Batch 800 Loss 0.0346
# Epoch 14 Batch 900 Loss 0.0490
# Epoch 14 Batch 1000 Loss 0.0714
# Epoch 14 Batch 1100 Loss 0.0500
# Epoch 14 Batch 1200 Loss 0.0833
# Epoch 14 Loss 0.0692
# Time per epoch 54.24194931983948 sec
#
# Epoch 15 Batch 0 Loss 0.0531
# Epoch 15 Batch 100 Loss 0.0380
# Epoch 15 Batch 200 Loss 0.0985
# Epoch 15 Batch 300 Loss 0.0553
# Epoch 15 Batch 400 Loss 0.0589
# Epoch 15 Batch 500 Loss 0.0784
# Epoch 15 Batch 600 Loss 0.0905
# Epoch 15 Batch 700 Loss 0.0635
# Epoch 15 Batch 800 Loss 0.0797
# Epoch 15 Batch 900 Loss 0.1109
# Epoch 15 Batch 1000 Loss 0.0621
# Epoch 15 Batch 1100 Loss 0.0651
# Epoch 15 Batch 1200 Loss 0.0509
# Epoch 15 Loss 0.0675
# Time per epoch 53.192240953445435 sec
#
# Epoch 16 Batch 0 Loss 0.0462
# Epoch 16 Batch 100 Loss 0.0283
# Epoch 16 Batch 200 Loss 0.0518
# Epoch 16 Batch 300 Loss 0.0752
# Epoch 16 Batch 400 Loss 0.0272
# Epoch 16 Batch 500 Loss 0.0553
# Epoch 16 Batch 600 Loss 0.0468
# Epoch 16 Batch 700 Loss 0.0663
# Epoch 16 Batch 800 Loss 0.0624
# Epoch 16 Batch 900 Loss 0.0575
# Epoch 16 Batch 1000 Loss 0.0703
# Epoch 16 Batch 1100 Loss 0.0674
# Epoch 16 Batch 1200 Loss 0.0695
# Epoch 16 Loss 0.0661
# Time per epoch 54.01635384559631 sec
#
# Epoch 17 Batch 0 Loss 0.0525
# Epoch 17 Batch 100 Loss 0.0392
# Epoch 17 Batch 200 Loss 0.0319
# Epoch 17 Batch 300 Loss 0.1047
# Epoch 17 Batch 400 Loss 0.0534
# Epoch 17 Batch 500 Loss 0.0383
# Epoch 17 Batch 600 Loss 0.0540
# Epoch 17 Batch 700 Loss 0.0579
# Epoch 17 Batch 800 Loss 0.0624
# Epoch 17 Batch 900 Loss 0.0615
# Epoch 17 Batch 1000 Loss 0.1086
# Epoch 17 Batch 1100 Loss 0.0972
# Epoch 17 Batch 1200 Loss 0.1155
# Epoch 17 Loss 0.0648
# Time per epoch 53.23300004005432 sec
#
# Epoch 18 Batch 0 Loss 0.0295
# Epoch 18 Batch 100 Loss 0.0798
# Epoch 18 Batch 200 Loss 0.0752
# Epoch 18 Batch 300 Loss 0.0593
# Epoch 18 Batch 400 Loss 0.0524
# Epoch 18 Batch 500 Loss 0.0342
# Epoch 18 Batch 600 Loss 0.0421
# Epoch 18 Batch 700 Loss 0.0425
# Epoch 18 Batch 800 Loss 0.0690
# Epoch 18 Batch 900 Loss 0.0863
# Epoch 18 Batch 1000 Loss 0.0491
# Epoch 18 Batch 1100 Loss 0.0755
# Epoch 18 Batch 1200 Loss 0.0894
# Epoch 18 Loss 0.0640
# Time per epoch 54.2344696521759 sec
#
# Epoch 19 Batch 0 Loss 0.0703
# Epoch 19 Batch 100 Loss 0.0427
# Epoch 19 Batch 200 Loss 0.0517
# Epoch 19 Batch 300 Loss 0.0624
# Epoch 19 Batch 400 Loss 0.0347
# Epoch 19 Batch 500 Loss 0.0257
# Epoch 19 Batch 600 Loss 0.0557
# Epoch 19 Batch 700 Loss 0.0338
# Epoch 19 Batch 800 Loss 0.0852
# Epoch 19 Batch 900 Loss 0.0730
# Epoch 19 Batch 1000 Loss 0.0885
# Epoch 19 Batch 1100 Loss 0.0642
# Epoch 19 Batch 1200 Loss 0.0363
# Epoch 19 Loss 0.0625
# Time per epoch 53.197195291519165 sec
#
# Epoch 20 Batch 0 Loss 0.0620
# Epoch 20 Batch 100 Loss 0.0278
# Epoch 20 Batch 200 Loss 0.0470
# Epoch 20 Batch 300 Loss 0.0454
# Epoch 20 Batch 400 Loss 0.0710
# Epoch 20 Batch 500 Loss 0.0626
# Epoch 20 Batch 600 Loss 0.0920
# Epoch 20 Batch 700 Loss 0.0507
# Epoch 20 Batch 800 Loss 0.0449
# Epoch 20 Batch 900 Loss 0.0577
# Epoch 20 Batch 1000 Loss 0.0542
# Epoch 20 Batch 1100 Loss 0.0822
# Epoch 20 Batch 1200 Loss 0.1392
# Epoch 20 Loss 0.0610
# Time per epoch 54.162835121154785 sec
#
# Epoch 21 Batch 0 Loss 0.0382
# Epoch 21 Batch 100 Loss 0.0405
# Epoch 21 Batch 200 Loss 0.0569
# Epoch 21 Batch 300 Loss 0.0511
# Epoch 21 Batch 400 Loss 0.0835
# Epoch 21 Batch 500 Loss 0.0825
# Epoch 21 Batch 600 Loss 0.0418
# Epoch 21 Batch 700 Loss 0.0414
# Epoch 21 Batch 800 Loss 0.0737
# Epoch 21 Batch 900 Loss 0.0350
# Epoch 21 Batch 1000 Loss 0.0609
# Epoch 21 Batch 1100 Loss 0.0723
# Epoch 21 Batch 1200 Loss 0.0929
# Epoch 21 Loss 0.0600
# Time per epoch 53.30351376533508 sec
#
# Epoch 22 Batch 0 Loss 0.0331
# Epoch 22 Batch 100 Loss 0.0605
# Epoch 22 Batch 200 Loss 0.0468
# Epoch 22 Batch 300 Loss 0.0793
# Epoch 22 Batch 400 Loss 0.0514
# Epoch 22 Batch 500 Loss 0.0461
# Epoch 22 Batch 600 Loss 0.0517
# Epoch 22 Batch 700 Loss 0.0592
# Epoch 22 Batch 800 Loss 0.0602
# Epoch 22 Batch 900 Loss 0.0913
# Epoch 22 Batch 1000 Loss 0.0928
# Epoch 22 Batch 1100 Loss 0.0843
# Epoch 22 Batch 1200 Loss 0.0919
# Epoch 22 Loss 0.0595
# Time per epoch 53.91385579109192 sec
#
# Epoch 23 Batch 0 Loss 0.0260
# Epoch 23 Batch 100 Loss 0.0570
# Epoch 23 Batch 200 Loss 0.0501
# Epoch 23 Batch 300 Loss 0.0486
# Epoch 23 Batch 400 Loss 0.0508
# Epoch 23 Batch 500 Loss 0.0438
# Epoch 23 Batch 600 Loss 0.0487
# Epoch 23 Batch 700 Loss 0.0682
# Epoch 23 Batch 800 Loss 0.0804
# Epoch 23 Batch 900 Loss 0.0595
# Epoch 23 Batch 1000 Loss 0.0750
# Epoch 23 Batch 1100 Loss 0.0758
# Epoch 23 Batch 1200 Loss 0.0805
# Epoch 23 Loss 0.0591
# Time per epoch 53.213658571243286 sec
#
# Epoch 24 Batch 0 Loss 0.0855
# Epoch 24 Batch 100 Loss 0.0341
# Epoch 24 Batch 200 Loss 0.0277
# Epoch 24 Batch 300 Loss 0.0344
# Epoch 24 Batch 400 Loss 0.0387
# Epoch 24 Batch 500 Loss 0.0437
# Epoch 24 Batch 600 Loss 0.0345
# Epoch 24 Batch 700 Loss 0.0665
# Epoch 24 Batch 800 Loss 0.0894
# Epoch 24 Batch 900 Loss 0.0454
# Epoch 24 Batch 1000 Loss 0.0414
# Epoch 24 Batch 1100 Loss 0.1184
# Epoch 24 Batch 1200 Loss 0.0515
# Epoch 24 Loss 0.0577
# Time per epoch 53.9227614402771 sec
#
# Epoch 25 Batch 0 Loss 0.0652
# Epoch 25 Batch 100 Loss 0.0273
# Epoch 25 Batch 200 Loss 0.0405
# Epoch 25 Batch 300 Loss 0.0399
# Epoch 25 Batch 400 Loss 0.0463
# Epoch 25 Batch 500 Loss 0.0573
# Epoch 25 Batch 600 Loss 0.0386
# Epoch 25 Batch 700 Loss 0.0608
# Epoch 25 Batch 800 Loss 0.0495
# Epoch 25 Batch 900 Loss 0.0581
# Epoch 25 Batch 1000 Loss 0.0660
# Epoch 25 Batch 1100 Loss 0.1153
# Epoch 25 Batch 1200 Loss 0.0660
# Epoch 25 Loss 0.0566
# Time per epoch 53.13937282562256 sec
#
# Epoch 26 Batch 0 Loss 0.0318
# Epoch 26 Batch 100 Loss 0.0556
# Epoch 26 Batch 200 Loss 0.0321
# Epoch 26 Batch 300 Loss 0.0453
# Epoch 26 Batch 400 Loss 0.0728
# Epoch 26 Batch 500 Loss 0.0884
# Epoch 26 Batch 600 Loss 0.0777
# Epoch 26 Batch 700 Loss 0.0773
# Epoch 26 Batch 800 Loss 0.0613
# Epoch 26 Batch 900 Loss 0.1005
# Epoch 26 Batch 1000 Loss 0.0796
# Epoch 26 Batch 1100 Loss 0.0737
# Epoch 26 Batch 1200 Loss 0.0695
# Epoch 26 Loss 0.0559
# Time per epoch 54.224809408187866 sec
#
# Epoch 27 Batch 0 Loss 0.0497
# Epoch 27 Batch 100 Loss 0.0354
# Epoch 27 Batch 200 Loss 0.0860
# Epoch 27 Batch 300 Loss 0.0488
# Epoch 27 Batch 400 Loss 0.0223
# Epoch 27 Batch 500 Loss 0.0527
# Epoch 27 Batch 600 Loss 0.0477
# Epoch 27 Batch 700 Loss 0.0609
# Epoch 27 Batch 800 Loss 0.0711
# Epoch 27 Batch 900 Loss 0.0721
# Epoch 27 Batch 1000 Loss 0.0483
# Epoch 27 Batch 1100 Loss 0.0650
# Epoch 27 Batch 1200 Loss 0.0508
# Epoch 27 Loss 0.0553
# Time per epoch 53.464521408081055 sec
#
# Epoch 28 Batch 0 Loss 0.0452
# Epoch 28 Batch 100 Loss 0.0234
# Epoch 28 Batch 200 Loss 0.0206
# Epoch 28 Batch 300 Loss 0.0743
# Epoch 28 Batch 400 Loss 0.0553
# Epoch 28 Batch 500 Loss 0.0448
# Epoch 28 Batch 600 Loss 0.0404
# Epoch 28 Batch 700 Loss 0.0483
# Epoch 28 Batch 800 Loss 0.0688
# Epoch 28 Batch 900 Loss 0.0500
# Epoch 28 Batch 1000 Loss 0.0457
# Epoch 28 Batch 1100 Loss 0.0218
# Epoch 28 Batch 1200 Loss 0.0884
# Epoch 28 Loss 0.0553
# Time per epoch 54.045695066452026 sec
#
# Epoch 29 Batch 0 Loss 0.0284
# Epoch 29 Batch 100 Loss 0.0466
# Epoch 29 Batch 200 Loss 0.0708
# Epoch 29 Batch 300 Loss 0.0381
# Epoch 29 Batch 400 Loss 0.0314
# Epoch 29 Batch 500 Loss 0.0532
# Epoch 29 Batch 600 Loss 0.0564
# Epoch 29 Batch 700 Loss 0.0268
# Epoch 29 Batch 800 Loss 0.0652
# Epoch 29 Batch 900 Loss 0.0487
# Epoch 29 Batch 1000 Loss 0.0741
# Epoch 29 Batch 1100 Loss 0.0597
# Epoch 29 Batch 1200 Loss 0.0352
# Epoch 29 Loss 0.0542
# Time per epoch 53.24896216392517 sec
#
# Epoch 30 Batch 0 Loss 0.0457
# Epoch 30 Batch 100 Loss 0.0471
# Epoch 30 Batch 200 Loss 0.0481
# Epoch 30 Batch 300 Loss 0.0374
# Epoch 30 Batch 400 Loss 0.0415
# Epoch 30 Batch 500 Loss 0.0396
# Epoch 30 Batch 600 Loss 0.0333
# Epoch 30 Batch 700 Loss 0.0276
# Epoch 30 Batch 800 Loss 0.0646
# Epoch 30 Batch 900 Loss 0.0825
# Epoch 30 Batch 1000 Loss 0.0687
# Epoch 30 Batch 1100 Loss 0.0482
# Epoch 30 Batch 1200 Loss 0.0549
# Epoch 30 Loss 0.0533
# Time per epoch 54.06304335594177 sec
#
# Epoch 31 Batch 0 Loss 0.0799
# Epoch 31 Batch 100 Loss 0.0429
# Epoch 31 Batch 200 Loss 0.0091
# Epoch 31 Batch 300 Loss 0.0585
# Epoch 31 Batch 400 Loss 0.0467
# Epoch 31 Batch 500 Loss 0.0689
# Epoch 31 Batch 600 Loss 0.0320
# Epoch 31 Batch 700 Loss 0.0412
# Epoch 31 Batch 800 Loss 0.0400
# Epoch 31 Batch 900 Loss 0.0754
# Epoch 31 Batch 1000 Loss 0.0483
# Epoch 31 Batch 1100 Loss 0.0506
# Epoch 31 Batch 1200 Loss 0.0978
# Epoch 31 Loss 0.0523
# Time per epoch 53.2356653213501 sec
#
# Epoch 32 Batch 0 Loss 0.0325
# Epoch 32 Batch 100 Loss 0.0512
# Epoch 32 Batch 200 Loss 0.0454
# Epoch 32 Batch 300 Loss 0.0398
# Epoch 32 Batch 400 Loss 0.0862
# Epoch 32 Batch 500 Loss 0.0542
# Epoch 32 Batch 600 Loss 0.0438
# Epoch 32 Batch 700 Loss 0.0457
# Epoch 32 Batch 800 Loss 0.0727
# Epoch 32 Batch 900 Loss 0.0900
# Epoch 32 Batch 1000 Loss 0.0575
# Epoch 32 Batch 1100 Loss 0.0407
# Epoch 32 Batch 1200 Loss 0.0762
# Epoch 32 Loss 0.0521
# Time per epoch 53.94986057281494 sec
#
# Epoch 33 Batch 0 Loss 0.0373
# Epoch 33 Batch 100 Loss 0.0855
# Epoch 33 Batch 200 Loss 0.0413
# Epoch 33 Batch 300 Loss 0.0405
# Epoch 33 Batch 400 Loss 0.0462
# Epoch 33 Batch 500 Loss 0.0732
# Epoch 33 Batch 600 Loss 0.0634
# Epoch 33 Batch 700 Loss 0.0651
# Epoch 33 Batch 800 Loss 0.0348
# Epoch 33 Batch 900 Loss 0.0638
# Epoch 33 Batch 1000 Loss 0.0529
# Epoch 33 Batch 1100 Loss 0.0524
# Epoch 33 Batch 1200 Loss 0.0252
# Epoch 33 Loss 0.0519
# Time per epoch 53.37239074707031 sec
#
# Epoch 34 Batch 0 Loss 0.0455
# Epoch 34 Batch 100 Loss 0.0261
# Epoch 34 Batch 200 Loss 0.0521
# Epoch 34 Batch 300 Loss 0.0331
# Epoch 34 Batch 400 Loss 0.0763
# Epoch 34 Batch 500 Loss 0.0410
# Epoch 34 Batch 600 Loss 0.0303
# Epoch 34 Batch 700 Loss 0.0291
# Epoch 34 Batch 800 Loss 0.0570
# Epoch 34 Batch 900 Loss 0.0855
# Epoch 34 Batch 1000 Loss 0.0577
# Epoch 34 Batch 1100 Loss 0.0724
# Epoch 34 Batch 1200 Loss 0.0878
# Epoch 34 Loss 0.0511
# Time per epoch 54.112192153930664 sec
#
# Epoch 35 Batch 0 Loss 0.0314
# Epoch 35 Batch 100 Loss 0.0609
# Epoch 35 Batch 200 Loss 0.0278
# Epoch 35 Batch 300 Loss 0.0407
# Epoch 35 Batch 400 Loss 0.0296
# Epoch 35 Batch 500 Loss 0.0303
# Epoch 35 Batch 600 Loss 0.0561
# Epoch 35 Batch 700 Loss 0.0847
# Epoch 35 Batch 800 Loss 0.0675
# Epoch 35 Batch 900 Loss 0.0364
# Epoch 35 Batch 1000 Loss 0.0766
# Epoch 35 Batch 1100 Loss 0.0548
# Epoch 35 Batch 1200 Loss 0.0428
# Epoch 35 Loss 0.0506
# Time per epoch 53.30639362335205 sec
#
# Epoch 36 Batch 0 Loss 0.0307
# Epoch 36 Batch 100 Loss 0.0203
# Epoch 36 Batch 200 Loss 0.0650
# Epoch 36 Batch 300 Loss 0.0609
# Epoch 36 Batch 400 Loss 0.0554
# Epoch 36 Batch 500 Loss 0.0288
# Epoch 36 Batch 600 Loss 0.0349
# Epoch 36 Batch 700 Loss 0.0342
# Epoch 36 Batch 800 Loss 0.0508
# Epoch 36 Batch 900 Loss 0.0959
# Epoch 36 Batch 1000 Loss 0.0518
# Epoch 36 Batch 1100 Loss 0.0597
# Epoch 36 Batch 1200 Loss 0.0428
# Epoch 36 Loss 0.0501
# Time per epoch 54.05096983909607 sec
#
# Epoch 37 Batch 0 Loss 0.0277
# Epoch 37 Batch 100 Loss 0.0405
# Epoch 37 Batch 200 Loss 0.0456
# Epoch 37 Batch 300 Loss 0.0523
# Epoch 37 Batch 400 Loss 0.0504
# Epoch 37 Batch 500 Loss 0.0520
# Epoch 37 Batch 600 Loss 0.0472
# Epoch 37 Batch 700 Loss 0.0605
# Epoch 37 Batch 800 Loss 0.0442
# Epoch 37 Batch 900 Loss 0.0914
# Epoch 37 Batch 1000 Loss 0.0387
# Epoch 37 Batch 1100 Loss 0.0630
# Epoch 37 Batch 1200 Loss 0.0747
# Epoch 37 Loss 0.0497
# Time per epoch 53.630714893341064 sec
#
# Epoch 38 Batch 0 Loss 0.0365
# Epoch 38 Batch 100 Loss 0.0435
# Epoch 38 Batch 200 Loss 0.0386
# Epoch 38 Batch 300 Loss 0.0535
# Epoch 38 Batch 400 Loss 0.0426
# Epoch 38 Batch 500 Loss 0.0544
# Epoch 38 Batch 600 Loss 0.0566
# Epoch 38 Batch 700 Loss 0.0254
# Epoch 38 Batch 800 Loss 0.0566
# Epoch 38 Batch 900 Loss 0.0586
# Epoch 38 Batch 1000 Loss 0.0659
# Epoch 38 Batch 1100 Loss 0.0373
# Epoch 38 Batch 1200 Loss 0.0494
# Epoch 38 Loss 0.0498
# Time per epoch 54.25303411483765 sec
#
# Epoch 39 Batch 0 Loss 0.0323
# Epoch 39 Batch 100 Loss 0.0207
# Epoch 39 Batch 200 Loss 0.0516
# Epoch 39 Batch 300 Loss 0.0412
# Epoch 39 Batch 400 Loss 0.0310
# Epoch 39 Batch 500 Loss 0.0478
# Epoch 39 Batch 600 Loss 0.0420
# Epoch 39 Batch 700 Loss 0.0467
# Epoch 39 Batch 800 Loss 0.0298
# Epoch 39 Batch 900 Loss 0.0692
# Epoch 39 Batch 1000 Loss 0.0414
# Epoch 39 Batch 1100 Loss 0.0345
# Epoch 39 Batch 1200 Loss 0.0421
# Epoch 39 Loss 0.0488
# Time per epoch 53.51266431808472 sec
#
# Epoch 40 Batch 0 Loss 0.0285
# Epoch 40 Batch 100 Loss 0.0255
# Epoch 40 Batch 200 Loss 0.0272
# Epoch 40 Batch 300 Loss 0.0491
# Epoch 40 Batch 400 Loss 0.0652
# Epoch 40 Batch 500 Loss 0.0427
# Epoch 40 Batch 600 Loss 0.0650
# Epoch 40 Batch 700 Loss 0.0584
# Epoch 40 Batch 800 Loss 0.0776
# Epoch 40 Batch 900 Loss 0.0435
# Epoch 40 Batch 1000 Loss 0.0610
# Epoch 40 Batch 1100 Loss 0.0841
# Epoch 40 Batch 1200 Loss 0.0552
# Epoch 40 Loss 0.0489
# Time per epoch 54.0067343711853 sec
#
# Epoch 41 Batch 0 Loss 0.0288
# Epoch 41 Batch 100 Loss 0.0332
# Epoch 41 Batch 200 Loss 0.0346
# Epoch 41 Batch 300 Loss 0.0387
# Epoch 41 Batch 400 Loss 0.0478
# Epoch 41 Batch 500 Loss 0.0375
# Epoch 41 Batch 600 Loss 0.0520
# Epoch 41 Batch 700 Loss 0.0294
# Epoch 41 Batch 800 Loss 0.0623
# Epoch 41 Batch 900 Loss 0.0737
# Epoch 41 Batch 1000 Loss 0.0547
# Epoch 41 Batch 1100 Loss 0.0509
# Epoch 41 Batch 1200 Loss 0.0342
# Epoch 41 Loss 0.0484
# Time per epoch 53.11697053909302 sec
#
# Epoch 42 Batch 0 Loss 0.0326
# Epoch 42 Batch 100 Loss 0.0441
# Epoch 42 Batch 200 Loss 0.0340
# Epoch 42 Batch 300 Loss 0.0406
# Epoch 42 Batch 400 Loss 0.0520
# Epoch 42 Batch 500 Loss 0.0320
# Epoch 42 Batch 600 Loss 0.0616
# Epoch 42 Batch 700 Loss 0.0168
# Epoch 42 Batch 800 Loss 0.0282
# Epoch 42 Batch 900 Loss 0.0579
# Epoch 42 Batch 1000 Loss 0.0427
# Epoch 42 Batch 1100 Loss 0.0562
# Epoch 42 Batch 1200 Loss 0.0735
# Epoch 42 Loss 0.0471
# Time per epoch 54.008711099624634 sec
#
# Epoch 43 Batch 0 Loss 0.0338
# Epoch 43 Batch 100 Loss 0.0413
# Epoch 43 Batch 200 Loss 0.0408
# Epoch 43 Batch 300 Loss 0.0174
# Epoch 43 Batch 400 Loss 0.0418
# Epoch 43 Batch 500 Loss 0.0574
# Epoch 43 Batch 600 Loss 0.0355
# Epoch 43 Batch 700 Loss 0.0444
# Epoch 43 Batch 800 Loss 0.0391
# Epoch 43 Batch 900 Loss 0.0704
# Epoch 43 Batch 1000 Loss 0.0412
# Epoch 43 Batch 1100 Loss 0.0626
# Epoch 43 Batch 1200 Loss 0.0430
# Epoch 43 Loss 0.0473
# Time per epoch 53.20593976974487 sec
#
# Epoch 44 Batch 0 Loss 0.0318
# Epoch 44 Batch 100 Loss 0.0494
# Epoch 44 Batch 200 Loss 0.0390
# Epoch 44 Batch 300 Loss 0.0326
# Epoch 44 Batch 400 Loss 0.0689
# Epoch 44 Batch 500 Loss 0.0602
# Epoch 44 Batch 600 Loss 0.0459
# Epoch 44 Batch 700 Loss 0.0520
# Epoch 44 Batch 800 Loss 0.0311
# Epoch 44 Batch 900 Loss 0.0436
# Epoch 44 Batch 1000 Loss 0.0457
# Epoch 44 Batch 1100 Loss 0.0697
# Epoch 44 Batch 1200 Loss 0.0627
# Epoch 44 Loss 0.0471
# Time per epoch 53.90203237533569 sec
#
# Epoch 45 Batch 0 Loss 0.0435
# Epoch 45 Batch 100 Loss 0.0404
# Epoch 45 Batch 200 Loss 0.0402
# Epoch 45 Batch 300 Loss 0.0291
# Epoch 45 Batch 400 Loss 0.0475
# Epoch 45 Batch 500 Loss 0.0548
# Epoch 45 Batch 600 Loss 0.0485
# Epoch 45 Batch 700 Loss 0.0449
# Epoch 45 Batch 800 Loss 0.0660
# Epoch 45 Batch 900 Loss 0.0525
# Epoch 45 Batch 1000 Loss 0.0481
# Epoch 45 Batch 1100 Loss 0.0549
# Epoch 45 Batch 1200 Loss 0.0397
# Epoch 45 Loss 0.0460
# Time per epoch 53.30052137374878 sec
#
# Epoch 46 Batch 0 Loss 0.0407
# Epoch 46 Batch 100 Loss 0.0404
# Epoch 46 Batch 200 Loss 0.0188
# Epoch 46 Batch 300 Loss 0.0487
# Epoch 46 Batch 400 Loss 0.0601
# Epoch 46 Batch 500 Loss 0.0279
# Epoch 46 Batch 600 Loss 0.0323
# Epoch 46 Batch 700 Loss 0.0239
# Epoch 46 Batch 800 Loss 0.0741
# Epoch 46 Batch 900 Loss 0.0381
# Epoch 46 Batch 1000 Loss 0.0597
# Epoch 46 Batch 1100 Loss 0.0456
# Epoch 46 Batch 1200 Loss 0.0410
# Epoch 46 Loss 0.0462
# Time per epoch 53.98807120323181 sec
#
# Epoch 47 Batch 0 Loss 0.0306
# Epoch 47 Batch 100 Loss 0.0404
# Epoch 47 Batch 200 Loss 0.0194
# Epoch 47 Batch 300 Loss 0.0155
# Epoch 47 Batch 400 Loss 0.0286
# Epoch 47 Batch 500 Loss 0.0535
# Epoch 47 Batch 600 Loss 0.0556
# Epoch 47 Batch 700 Loss 0.0626
# Epoch 47 Batch 800 Loss 0.0437
# Epoch 47 Batch 900 Loss 0.0557
# Epoch 47 Batch 1000 Loss 0.0476
# Epoch 47 Batch 1100 Loss 0.0470
# Epoch 47 Batch 1200 Loss 0.0532
# Epoch 47 Loss 0.0462
# Time per epoch 53.272807598114014 sec
#
# Epoch 48 Batch 0 Loss 0.0429
# Epoch 48 Batch 100 Loss 0.0529
# Epoch 48 Batch 200 Loss 0.0373
# Epoch 48 Batch 300 Loss 0.0448
# Epoch 48 Batch 400 Loss 0.0411
# Epoch 48 Batch 500 Loss 0.0305
# Epoch 48 Batch 600 Loss 0.0256
# Epoch 48 Batch 700 Loss 0.0496
# Epoch 48 Batch 800 Loss 0.0328
# Epoch 48 Batch 900 Loss 0.0566
# Epoch 48 Batch 1000 Loss 0.0468
# Epoch 48 Batch 1100 Loss 0.0556
# Epoch 48 Batch 1200 Loss 0.0247
# Epoch 48 Loss 0.0456
# Time per epoch 53.948996782302856 sec
#
# Epoch 49 Batch 0 Loss 0.0567
# Epoch 49 Batch 100 Loss 0.0321
# Epoch 49 Batch 200 Loss 0.0346
# Epoch 49 Batch 300 Loss 0.0291
# Epoch 49 Batch 400 Loss 0.0861
# Epoch 49 Batch 500 Loss 0.0613
# Epoch 49 Batch 600 Loss 0.0429
# Epoch 49 Batch 700 Loss 0.0257
# Epoch 49 Batch 800 Loss 0.0371
# Epoch 49 Batch 900 Loss 0.0536
# Epoch 49 Batch 1000 Loss 0.0426
# Epoch 49 Batch 1100 Loss 0.0299
# Epoch 49 Batch 1200 Loss 0.0529
# Epoch 49 Loss 0.0458
# Time per epoch 53.303879737854004 sec
#
# Epoch 50 Batch 0 Loss 0.0359
# Epoch 50 Batch 100 Loss 0.0222
# Epoch 50 Batch 200 Loss 0.0341
# Epoch 50 Batch 300 Loss 0.0363
# Epoch 50 Batch 400 Loss 0.0375
# Epoch 50 Batch 500 Loss 0.0408
# Epoch 50 Batch 600 Loss 0.0324
# Epoch 50 Batch 700 Loss 0.0424
# Epoch 50 Batch 800 Loss 0.0418
# Epoch 50 Batch 900 Loss 0.0327
# Epoch 50 Batch 1000 Loss 0.0811
# Epoch 50 Batch 1100 Loss 0.0803
# Epoch 50 Batch 1200 Loss 0.0534
# Epoch 50 Loss 0.0451
# Time per epoch 54.88464283943176 sec

# %%
def evaluate(sentence):
    attention_plot = np.zeros((max_length_targ, max_length_inp))
    
    sentence = preprocess_sentence(sentence)
    
    inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
   
    inputs = tf.convert_to_tensor(inputs)

    result = ''

    hidden = [tf.zeros((1, units))]
    
    enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden)

        predicted_id = tf.argmax(predictions[0]).numpy()

        result += targ_lang.index_word[predicted_id] + ' '

        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence

    dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)
  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %%
checkpoint_dir = '/content/'
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('Здесь хорошо.')
# Out:
# Input: <start> здесь хорошо . <end>
# Predicted translation: it's here here . . . . . . . .

# %%
translate('Учиться в радость.')
# Out:
# Input: <start> учиться в радость . <end>
# Predicted translation: let for to . . . . . . . .

# %%
translate('Как ваши дела?')
# Out:
# Input: <start> как ваши дела ? <end>
# Predicted translation: how are are you ? ? ? ? ? ? ?

# %%
translate('Привет')
# Out:
# Input: <start> привет <end>
# Predicted translation: hi and and sheep . . . . . . .

# %%
#!mkdir /content/checkpoint_dir

# %%
#!cp -r /content/ /content/checkpoint_dir/

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#!cp -r /content/checkpoint_dir/ /content/drive/MyDrive/work/GB_NLP/checkpoint_dir

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------------
# absl-py                       1.4.0
# aeppl                         0.0.33
# aesara                        2.7.9
# aiohttp                       3.8.4
# aiosignal                     1.3.1
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.12.1
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atari-py                      0.2.9
# atomicwrites                  1.4.1
# attrs                         22.2.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.11.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        6.0.0
# blis                          0.7.9
# bokeh                         2.3.3
# branca                        0.6.0
# bs4                           0.0.1
# CacheControl                  0.12.11
# cachetools                    5.3.0
# catalogue                     2.0.8
# certifi                       2022.12.7
# cffi                          1.15.1
# cftime                        1.6.2
# chardet                       4.0.0
# charset-normalizer            3.0.1
# click                         7.1.2
# clikit                        0.6.2
# cloudpickle                   2.2.1
# cmake                         3.22.6
# cmdstanpy                     1.1.0
# colorcet                      3.0.1
# colorlover                    0.3.0
# community                     1.0.0b1
# confection                    0.0.4
# cons                          0.4.5
# contextlib2                   0.5.5
# convertdate                   2.4.0
# crashtest                     0.3.1
# crcmod                        1.7
# cufflinks                     0.17.3
# cupy-cuda11x                  11.0.0
# cvxopt                        1.3.0
# cvxpy                         1.2.3
# cycler                        0.11.0
# cymem                         2.0.7
# Cython                        0.29.33
# daft                          0.0.4
# dask                          2022.2.1
# datascience                   0.17.5
# db-dtypes                     1.0.5
# dbus-python                   1.2.16
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.7.1
# descartes                     1.1.0
# dill                          0.3.6
# distributed                   2022.2.1
# dlib                          19.24.0
# dm-tree                       0.1.8
# dnspython                     2.3.0
# docutils                      0.16
# dopamine-rl                   1.0.5
# earthengine-api               0.1.341
# easydict                      1.10
# ecos                          2.0.12
# editdistance                  0.5.3
# en-core-web-sm                3.4.1
# entrypoints                   0.4
# ephem                         4.1.4
# et-xmlfile                    1.1.0
# etils                         1.0.0
# etuples                       0.3.8
# fa2                           0.3.5
# fastai                        2.7.11
# fastcore                      1.5.28
# fastdownload                  0.0.7
# fastdtw                       0.3.4
# fastjsonschema                2.16.2
# fastprogress                  1.0.3
# fastrlock                     0.8.1
# feather-format                0.4.1
# filelock                      3.9.0
# firebase-admin                5.3.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.4
# flatbuffers                   23.1.21
# folium                        0.12.1.post1
# frozenlist                    1.3.3
# fsspec                        2023.1.0
# future                        0.16.0
# gast                          0.4.0
# GDAL                          3.3.2
# gdown                         4.4.0
# gensim                        3.6.0
# geographiclib                 1.52
# geopy                         1.17.0
# gin-config                    0.5.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               2.11.0
# google-api-python-client      2.70.0
# google-auth                   2.16.0
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         3.4.2
# google-cloud-bigquery-storage 2.18.1
# google-cloud-core             2.3.2
# google-cloud-datastore        2.11.1
# google-cloud-firestore        2.7.3
# google-cloud-language         2.6.1
# google-cloud-storage          2.7.0
# google-cloud-translate        3.8.4
# google-colab                  1.0.0
# google-crc32c                 1.5.0
# google-pasta                  0.2.0
# google-resumable-media        2.4.1
# googleapis-common-protos      1.58.0
# googledrivedownloader         0.4
# graphviz                      0.10.1
# greenlet                      2.0.2
# grpcio                        1.51.1
# grpcio-status                 1.48.2
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.25.2
# gym-notices                   0.0.8
# h5py                          3.1.0
# HeapDict                      1.0.1
# hijri-converter               2.2.4
# holidays                      0.19
# holoviews                     1.14.9
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httpstan                      4.6.1
# humanize                      0.5.1
# hyperopt                      0.1.2
# idna                          2.10
# imageio                       2.9.0
# imagesize                     1.4.1
# imbalanced-learn              0.8.1
# imblearn                      0.0
# imgaug                        0.4.0
# importlib-metadata            6.0.0
# importlib-resources           5.10.2
# imutils                       0.5.4
# inflect                       2.1.0
# intel-openmp                  2023.0.0
# intervaltree                  2.1.0
# ipykernel                     5.3.4
# ipython                       7.9.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.7.1
# itsdangerous                  1.1.0
# jax                           0.3.25
# jaxlib                        0.3.25+cuda11.cudnn805
# jieba                         0.42.1
# Jinja2                        2.11.3
# joblib                        1.2.0
# jpeg4py                       0.1.4
# jsonschema                    4.3.3
# jupyter-client                6.1.12
# jupyter-console               6.1.0
# jupyter_core                  5.2.0
# jupyterlab-widgets            3.0.5
# kaggle                        1.5.12
# kapre                         0.3.7
# keras                         2.11.0
# keras-vis                     0.4.1
# kiwisolver                    1.4.4
# korean-lunar-calendar         0.3.1
# langcodes                     3.3.0
# libclang                      15.0.6.1
# librosa                       0.8.1
# lightgbm                      2.2.3
# llvmlite                      0.39.1
# lmdb                          0.99
# locket                        1.0.0
# logical-unification           0.4.5
# LunarCalendar                 0.0.9
# lxml                          4.9.2
# Markdown                      3.4.1
# MarkupSafe                    2.0.1
# marshmallow                   3.19.0
# matplotlib                    3.2.2
# matplotlib-venn               0.11.7
# miniKanren                    1.0.3
# missingno                     0.5.1
# mistune                       0.8.4
# mizani                        0.7.3
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                9.0.0
# moviepy                       0.2.3.5
# mpmath                        1.2.1
# msgpack                       1.0.4
# multidict                     6.0.4
# multipledispatch              0.6.0
# multitasking                  0.0.11
# murmurhash                    1.0.9
# music21                       5.5.0
# natsort                       5.5.0
# nbconvert                     5.6.1
# nbformat                      5.7.3
# netCDF4                       1.6.2
# networkx                      3.0
# nibabel                       3.0.2
# nltk                          3.7
# notebook                      6.3.0
# numba                         0.56.4
# numexpr                       2.8.4
# numpy                         1.21.6
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# okgrade                       0.4.3
# opencv-contrib-python         4.6.0.66
# opencv-python                 4.6.0.66
# opencv-python-headless        4.7.0.68
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# osqp                          0.6.2.post0
# packaging                     23.0
# palettable                    3.3.0
# pandas                        1.3.5
# pandas-datareader             0.9.0
# pandas-gbq                    0.17.9
# pandas-profiling              1.4.1
# pandocfilters                 1.5.0
# panel                         0.12.1
# param                         1.12.3
# parso                         0.8.3
# partd                         1.3.0
# pastel                        0.2.1
# pathlib                       1.0.1
# pathy                         0.10.1
# patsy                         0.5.3
# pep517                        0.13.0
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        7.1.2
# pip                           22.0.4
# pip-tools                     6.6.2
# platformdirs                  3.0.0
# plotly                        5.5.0
# plotnine                      0.8.0
# pluggy                        0.7.1
# pooch                         1.6.0
# portpicker                    1.3.9
# prefetch-generator            1.0.3
# preshed                       3.0.8
# prettytable                   3.6.0
# progressbar2                  3.38.0
# prometheus-client             0.16.0
# promise                       2.3
# prompt-toolkit                2.0.10
# prophet                       1.1.2
# proto-plus                    1.22.2
# protobuf                      3.19.6
# psutil                        5.4.8
# psycopg2                      2.9.5
# ptyprocess                    0.7.0
# py                            1.11.0
# pyarrow                       9.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.6
# pycparser                     2.21
# pyct                          0.5.0
# pydantic                      1.10.4
# pydata-google-auth            1.7.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyemd                         0.5.1
# pyerfa                        2.0.0.1
# Pygments                      2.6.1
# PyGObject                     3.36.0
# pylev                         1.4.0
# pymc                          4.1.4
# PyMeeus                       0.5.12
# pymongo                       4.3.3
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     3.0.9
# pyrsistent                    0.19.3
# pysimdjson                    3.2.0
# PySocks                       1.7.1
# pystan                        3.3.0
# pytest                        3.6.4
# python-apt                    2.0.1
# python-dateutil               2.8.2
# python-louvain                0.16
# python-slugify                8.0.0
# python-utils                  3.5.2
# pytz                          2022.7.1
# pyviz-comms                   2.2.1
# PyWavelets                    1.4.1
# PyYAML                        6.0
# pyzmq                         23.2.1
# qdldl                         0.1.5.post3
# qudida                        0.0.4
# regex                         2022.6.2
# requests                      2.25.1
# requests-oauthlib             1.3.1
# requests-unixsocket           0.2.0
# resampy                       0.4.2
# rpy2                          3.5.5
# rsa                           4.9
# scikit-image                  0.18.3
# scikit-learn                  1.0.2
# scipy                         1.7.3
# screen-resolution-extra       0.0.0
# scs                           3.2.2
# seaborn                       0.11.2
# Send2Trash                    1.8.0
# setuptools                    57.4.0
# shapely                       2.0.1
# six                           1.15.0
# sklearn-pandas                1.8.0
# smart-open                    6.3.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soundfile                     0.12.1
# spacy                         3.4.4
# spacy-legacy                  3.0.12
# spacy-loggers                 1.0.4
# Sphinx                        3.5.4
# sphinxcontrib-applehelp       1.0.4
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.1
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# SQLAlchemy                    1.4.46
# sqlparse                      0.4.3
# srsly                         2.4.5
# statsmodels                   0.12.2
# sympy                         1.7.1
# tables                        3.7.0
# tabulate                      0.8.10
# tblib                         1.7.0
# tenacity                      8.2.1
# tensorboard                   2.11.2
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.11.0
# tensorflow-datasets           4.8.2
# tensorflow-estimator          2.11.0
# tensorflow-gcs-config         2.11.0
# tensorflow-hub                0.12.0
# tensorflow-io-gcs-filesystem  0.30.0
# tensorflow-metadata           1.12.0
# tensorflow-probability        0.19.0
# termcolor                     2.2.0
# terminado                     0.13.3
# testpath                      0.6.0
# text-unidecode                1.3
# textblob                      0.15.3
# thinc                         8.1.7
# threadpoolctl                 3.1.0
# tifffile                      2023.2.3
# toml                          0.10.2
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         1.13.1+cu116
# torchaudio                    0.13.1+cu116
# torchsummary                  1.5.1
# torchtext                     0.14.1
# torchvision                   0.14.1+cu116
# tornado                       6.2
# tqdm                          4.64.1
# traitlets                     5.7.1
# tweepy                        3.10.0
# typeguard                     2.7.1
# typer                         0.7.0
# typing_extensions             4.5.0
# tzlocal                       1.5.1
# uritemplate                   4.1.1
# urllib3                       1.24.3
# vega-datasets                 0.9.0
# wasabi                        0.10.1
# wcwidth                       0.2.6
# webargs                       8.2.0
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wheel                         0.38.4
# widgetsnbextension            3.6.2
# wordcloud                     1.8.2.2
# wrapt                         1.14.1
# xarray                        2022.12.0
# xarray-einstats               0.5.1
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.2.0
# xlwt                          1.3.0
# yarl                          1.8.2
# yellowbrick                   1.5
# zict                          2.2.0
# zipp                          3.13.0

# %%
# !pip install numpy scipy librosa unidecode inflect librosa transformers
# !pip install deeppavlov
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.9/235.9 KB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 63.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 48.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 1.3 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.7/433.7 KB 31.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 KB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.2/145.2 KB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 KB 2.4 MB/s eta 0:00:00
# ...

# %%
# !python -m deeppavlov install squad_ru_bert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 96.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.26.1
#     Uninstalling transformers-4.26.1:
#       Successfully uninstalled transformers-4.26.1
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ### RuBERT for question answering.
# Here we will use the model pre-trained on the SberQuAD dataset from the [SDSJ-2017 challenge problem B](https://github.com/sberbank-ai/data-science-journey-2017/tree/master/problem_B).

# %%
from deeppavlov import build_model, configs
model_ru = build_model('squad_ru_bert', download=True)
# Out:
# 2023-02-27 08:11:07.412 INFO in 'deeppavlov.core.data.utils'['utils'] at line 95: Downloading from http://files.deeppavlov.ai/v1/squad/squad_ru_torch_bert.tar.gz to /root/.deeppavlov/squad_ru_torch_bert.tar.gz
# INFO:deeppavlov.core.data.utils:Downloading from http://files.deeppavlov.ai/v1/squad/squad_ru_torch_bert.tar.gz to /root/.deeppavlov/squad_ru_torch_bert.tar.gz
# 100%|██████████| 1.74G/1.74G [02:30<00:00, 11.6MB/s]
# 2023-02-27 08:13:38.868 INFO in 'deeppavlov.core.data.utils'['utils'] at line 276: Extracting /root/.deeppavlov/squad_ru_torch_bert.tar.gz archive into /root/.deeppavlov/models
# INFO:deeppavlov.core.data.utils:Extracting /root/.deeppavlov/squad_ru_torch_bert.tar.gz archive into /root/.deeppavlov/models
# ...

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Import the necessary modules
from tensorflow.keras.preprocessing.text import Tokenizer

# Read in the text file
text = open('my_file.txt', 'r', encoding='utf-8').read()

# %%
text1 = 'Hi all'
print(len(text.split()))
# Out:
# 703

# %%
# !python -m deeppavlov install bert_preprocessor
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.8/dist-packages/deeppavlov/__main__.py", line 4, in <module>
#     main()
#   File "/usr/local/lib/python3.8/dist-packages/deeppavlov/deep.py", line 72, in main
#     install_from_config(pipeline_config_path)
#   File "/usr/local/lib/python3.8/dist-packages/deeppavlov/utils/pip_wrapper/pip_wrapper.py", line 56, in install_from_config
#     requirements_files = get_config_requirements(config)
#   File "/usr/local/lib/python3.8/dist-packages/deeppavlov/utils/pip_wrapper/pip_wrapper.py", line 43, in get_config_requirements
#     config = parse_config(config)
#   File "/usr/local/lib/python3.8/dist-packages/deeppavlov/core/commands/utils.py", line 121, in parse_config
# ...

# %%
#from deeppavlov.models.preprocessors.bert_preprocessor import BertPreprocessor
import deeppavlov.models.preprocessors.odqa_preprocessors.StringMultiplie
'''
bert_preprocessor = BertPreprocessor(
    bert_model="squad_ru_bert",
    do_lower_case=True
)

#my_sequence = "This is a sequence of text"

subtokens = bert_preprocessor.split_into_subtokens(text)
'''
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-6efe87754d65> in <module>
#       1 #from deeppavlov.models.preprocessors.bert_preprocessor import BertPreprocessor
# ----> 2 import deeppavlov.models.preprocessors.odqa_preprocessors.StringMultiplie
#       3 '''
#       4 bert_preprocessor = BertPreprocessor(
#       5     bert_model="squad_ru_bert",
#
# ModuleNotFoundError: No module named 'deeppavlov.models.preprocessors.odqa_preprocessors.StringMultiplie'; 'deeppavlov.models.preprocessors.odqa_preprocessors' is not a package
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %%
model_ru([text.lower()], ['ГЕМАРТРОЗА?'.lower()])
# Out:
# [['кровоизлияние в полость сустава'], [713], [0.9999934434890747]]

# %%
model_ru([text], ['Что такое Опорно-двигательная?'])
# Out:
# [['наиболее частая форма первичного нефротического синдрома'], [88], [1.0]]

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 63.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 9.2 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
qa_pipeline = pipeline(
    "question-answering",
    model="Den4ikAI/rubert_large_squad_2",
    tokenizer="Den4ikAI/rubert_large_squad_2"
)

# %%
text1 = "Эпилепсия - это заболевание головного мозга, характеризующееся повторными приступами нарушений двигательных, чувствительных, мыслительных или психических функций, возникающих вследствие чрезмерных нейронных разрядов в коре головного мозга."

# %%
# text = "Эпилепсия - это заболевание головного мозга, характеризующееся повторными приступами нарушений двигательных, чувствительных, мыслительных или психических функций, возникающих вследствие чрезмерных нейронных разрядов в коре головного мозга."
predictions = qa_pipeline({
    'context': text.lower(),
    'question': "что такое АНКИЛОЗ".lower()
})
print(predictions['answer'])
print(predictions)
# Out:
# это неподвижность в суставе как исход патологических изменений в нем
# {'score': 0.43802568316459656, 'start': 403, 'end': 471, 'answer': 'это неподвижность в суставе как исход патологических изменений в нем'}

# %%
text = "Эпилепсия - это заболевание головного мозга, характеризующееся повторными приступами нарушений двигательных, чувствительных, мыслительных или психических функций, возникающих вследствие чрезмерных нейронных разрядов в коре головного мозга."
string2 = "Пневмония - это острое инфекционное заболевание, для которого характерно развитие воспаления легочной ткани, обязательно в процесс вовлекаются альвеолы."
text += ' ' + string2
print(text)
# Out:
# Эпилепсия - это заболевание головного мозга, характеризующееся повторными приступами нарушений двигательных, чувствительных, мыслительных или психических функций, возникающих вследствие чрезмерных нейронных разрядов в коре головного мозга. Пневмония - это острое инфекционное заболевание, для которого характерно развитие воспаления легочной ткани, обязательно в процесс вовлекаются альвеолы.

# %%
# my_string = "Hello World"
with open("my_file.txt", "w") as f:
   f.write(text)

# %%
text = open('my_file.txt', 'r', encoding='utf-8').read()

# %%
text
# Out:
# 'Эпилепсия - это заболевание головного мозга, характеризующееся повторными приступами нарушений двигательных, чувствительных, мыслительных или психических функций, возникающих вследствие чрезмерных нейронных разрядов в коре головного мозга. Пневмония - это острое инфекционное заболевание, для которого характерно развитие воспаления легочной ткани, обязательно в процесс вовлекаются альвеолы.\nАНКИЛОЗ – это неподвижность в суставе как исход патологических изменений в нем. Возникает в результате воспалительных изменений в суставе, а также после тяжелых внутрисуставных переломов, связанных с разрушением суставных поверхностей. Особенно часто анкилоз образуется после открытых травм сустава, сопровождающихся развитием в нем длительно текущего нагноительного процесса. При этом наступает дегенерация хрящевого покрова суставных поверхностей с разрастанием соединительной фиброзной (фиброзный анкилоз) или костной (костный анкилоз) ткани. Длительное пребывание в гипсовой повязке также способству
# ...

# %% [markdown]
# # Урок 4. Сверточные нейронные сети
# # Домашнее задание

# %% [markdown]
# ### <span class="burk">Задание 1.</span>
# **Попробуйте улучшить точность распознавания образов cifar 10 сверточной нейронной
# сетью, рассмотренной на уроке. Приложите анализ с описанием того, что улучшает
# работу нейронной сети, а что ухудшает.**

# %%
from tensorflow import keras 
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import os

# %%
# установка параметров нейросети
batch_size = 128
num_classes = 10
epochs = 5
data_augmentation = True
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# %%
# разделение тренировочной и тестовой выборки
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'тренировочные примеры')
print(x_test.shape[0], 'тестовые примеры')

# преобразование матрицы чисел 0-9 в бинарную матрицу чисел 0-1
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 тренировочные примеры
# 10000 тестовые примеры

# %%
def plot_images(images, labels):
  fig, axes = plt.subplots(1, len(images), figsize = (10, 5))
  for im, l, ax in zip(images, labels, axes):
    ax.imshow(im.reshape(32, 32, 3))
    ax.set_title(l.argmax())

# %%
plot_images(x_train[:10], y_train[10:20])

# %%
datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)

# %%
datagen[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-5c0b362d5e84> in <module>()
# ----> 1 datagen[0]
#
# TypeError: 'ImageDataGenerator' object is not subscriptable

# %%
dg = datagen.flow(x_train[:5], batch_size=1)

# %%
dg[0]

# %%
plot_images(dg, y_train[:5])

# %%
# конфигурирование слоев нейросети
model = Sequential()

# слои нейросети отвественные за свертку и max-pooling
model.add(Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# полносвязные слои нейронной сети
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
# инициализация RMSprop optimizer
opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

# компиляция модели
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
# запуск data augmentation через fit_generator
model.fit_generator(datagen.flow(x_train, y_train,
                                  batch_size=batch_size),
                    epochs=epochs,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 391/391 [==============================] - 29s 70ms/step - loss: 2.0226 - accuracy: 0.2541 - val_loss: 1.7730 - val_accuracy: 0.3734
# Epoch 2/5
# 391/391 [==============================] - 27s 70ms/step - loss: 1.7758 - accuracy: 0.3539 - val_loss: 1.6018 - val_accuracy: 0.4282
# Epoch 3/5
# 391/391 [==============================] - 27s 69ms/step - loss: 1.6702 - accuracy: 0.3949 - val_loss: 1.5273 - val_accuracy: 0.4458
# Epoch 4/5
# 391/391 [==============================] - 27s 68ms/step - loss: 1.5937 - accuracy: 0.4191 - val_loss: 1.5071 - val_accuracy: 0.4522
# Epoch 5/5
# 391/391 [==============================] - 28s 71ms/step - loss: 1.5302 - accuracy: 0.4463 - val_loss: 1.4181 - val_accuracy: 0.4832

# %%
# сохранение модели и весов
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('сохранить обученную модель как %s ' % model_path)
# Out:
# сохранить обученную модель как /content/saved_models/keras_cifar10_trained_model.h5

# %%
# проверка работы обученной модели
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.4181 - accuracy: 0.4832
# Test loss: 1.4181032180786133
# Test accuracy: 0.4832000136375427

# %% [markdown]
# ### <span class="girk">Выводы:</span>

# %% [markdown]
# ### <span class="burk">Задание 2.</span>
# **Опишите в анализе, какие изменения необходимо было бы внести в получившуюся
# нейронную сеть, если бы ей нужно было работать не с cifar10, а с MNIST, CIFAR100 и
# IMAGENET.**

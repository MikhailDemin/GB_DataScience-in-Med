# %% [markdown]
# # Урок 4. Сверточные нейронные сети
# # Домашнее задание

# %% [markdown]
# ### <span class="burk">Задание 1.</span>
# **Попробуйте улучшить точность распознавания образов cifar 10 сверточной нейронной
# сетью, рассмотренной на уроке. Приложите анализ с описанием того, что улучшает
# работу нейронной сети, а что ухудшает.**

# %%
import random as python_random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, GlobalMaxPooling2D, AveragePooling2D
import os

# %%
# установка параметров нейросети
batch_size = 128
num_classes = 10
epochs = 8
data_augmentation = True
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# %%
# разделение тренировочной и тестовой выборки
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'тренировочные примеры')
print(x_test.shape[0], 'тестовые примеры')

# преобразование матрицы чисел 0-9 в бинарную матрицу чисел 0-1
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 тренировочные примеры
# 10000 тестовые примеры

# %%
def plot_images(images, labels):
  fig, axes = plt.subplots(1, len(images), figsize = (10, 5))
  for im, l, ax in zip(images, labels, axes):
    ax.imshow(im.reshape(32, 32, 3))
    ax.set_title(l.argmax())

# %%
plot_images(x_train[:10], y_train[10:20])

# %%
datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)

# %%
datagen[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-5c0b362d5e84> in <module>()
# ----> 1 datagen[0]
#
# TypeError: 'ImageDataGenerator' object is not subscriptable

# %%
dg = datagen.flow(x_train[:5], batch_size=1)

# %%
dg[0]
# Out:
# array([[[[0.43534094, 0.2976839 , 0.17174943],
#          [0.47325358, 0.33263907, 0.19431874],
#          [0.49105522, 0.34738073, 0.20458606],
#          ...,
#          [0.18188997, 0.10289191, 0.03469247],
#          [0.104975  , 0.07105233, 0.03915403],
#          [0.11133785, 0.09577998, 0.07570363]],
#
#         [[0.35871765, 0.23826249, 0.13289155],
#          [0.41168627, 0.28011656, 0.15193391],
#          [0.44486454, 0.30232176, 0.16175728],
#          ...,
#          [0.28035566, 0.16807115, 0.07267067],
#          [0.17156893, 0.10369658, 0.04897224],
#          [0.15767135, 0.10967552, 0.07331599]],
#
#         [[0.21541868, 0.1194682 , 0.05787351],
#          [0.26542526, 0.15613398, 0.06795352],
#          [0.3413772 , 0.2159792 , 0.09829398],
#          ...,
#          [0.34722576, 0.2174571 , 0.1036887 ],
#          [0.25318748, 0.1564867 , 0.07929444],
#          [0.23098733, 0.15208745, 0.09565157]],
#
#         ...,
#
#         [[0.534039  , 0.40877852, 0.30450413],
#          [0.71214235, 0.58457655, 0.4327839 ],
#          [0.76214606, 0.6403477 , 0.48256612],
#          ...,
#          [0.6816556 , 0.5328657 , 0.354098  ],
#          [0.6754369 , 0.53357136, 0.40923792],
#          [0.69411767, 0.5647059 , 0.45490196]],
#
#         [[0.534039  , 0.40877852, 0.30450413],
#          [0.71214235, 0.58457655, 0.4327839 ],
#          [0.76214606, 0.6403477 , 0.48256612],
#          ...,
#          [0.6816556 , 0.5328657 , 0.354098  ],
#          [0.6754369 , 0.53357136, 0.40923792],
#          [0.69411767, 0.5647059 , 0.45490196]],
#
#         [[0.534039  , 0.40877852, 0.30450413],
#          [0.71214235, 0.58457655, 0.4327839 ],
#          [0.76214606, 0.6403477 , 0.48256612],
#          ...,
#          [0.6816556 , 0.5328657 , 0.354098  ],
#          [0.6754369 , 0.53357136, 0.40923792],
#          [0.69411767, 0.5647059 , 0.45490196]]]], dtype=float32)

# %%
plot_images(dg, y_train[:5])

# %%
# конфигурирование слоев нейросети
model = Sequential()

# слои нейросети отвественные за свертку и max-pooling
model.add(Conv2D(32, (2, 2), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('tanh'))
model.add(Conv2D(32, (1, 1)))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=(1, 1)))
model.add(Dropout(0.1))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('tanh'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('tanh'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

# полносвязные слои нейронной сети
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('tanh'))
model.add(Dropout(0.1))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
# # конфигурирование слоев нейросети
# model = Sequential()

# # слои нейросети отвественные за свертку и max-pooling
# model.add(Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:]))
# model.add(Activation('tanh'))
# model.add(Conv2D(32, (3, 3)))
# model.add(Activation('tanh'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.06))

# model.add(Conv2D(64, (3, 3), padding='same'))
# model.add(Activation('tanh'))
# model.add(Conv2D(64, (3, 3)))
# model.add(Activation('tanh'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.06))

# # полносвязные слои нейронной сети
# model.add(Flatten())
# model.add(Dense(512))
# model.add(Activation('tanh'))
# model.add(Dropout(0.12))
# model.add(Dense(num_classes))
# model.add(Activation('softmax'))

# %%
# инициализация RMSprop optimizer
opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

# компиляция модели
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
# запуск data augmentation через fit_generator
model.fit(datagen.flow(x_train, y_train,
                                  batch_size=batch_size),
                    epochs=epochs,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/8
# 391/391 [==============================] - 25s 63ms/step - loss: 1.8679 - accuracy: 0.3443 - val_loss: 2.0920 - val_accuracy: 0.3078
# Epoch 2/8
# 391/391 [==============================] - 24s 61ms/step - loss: 1.6771 - accuracy: 0.4068 - val_loss: 1.8164 - val_accuracy: 0.3789
# Epoch 3/8
# 391/391 [==============================] - 24s 61ms/step - loss: 1.5587 - accuracy: 0.4480 - val_loss: 1.4908 - val_accuracy: 0.4849
# Epoch 4/8
# 391/391 [==============================] - 23s 60ms/step - loss: 1.4450 - accuracy: 0.4898 - val_loss: 1.3381 - val_accuracy: 0.5346
# Epoch 5/8
# 391/391 [==============================] - 24s 61ms/step - loss: 1.3593 - accuracy: 0.5187 - val_loss: 1.2385 - val_accuracy: 0.5661
# Epoch 6/8
# 391/391 [==============================] - 24s 62ms/step - loss: 1.2834 - accuracy: 0.5491 - val_loss: 1.1373 - val_accuracy: 0.6051
# Epoch 7/8
# 391/391 [==============================] - 23s 60ms/step - loss: 1.2254 - accuracy: 0.5689 - val_loss: 1.1791 - val_accuracy: 0.5888
# Epoch 8/8
# 391/391 [==============================] - 23s 60ms/step - loss: 1.1823 - accuracy: 0.5867 - val_loss: 1.0953 - val_accuracy: 0.6230

# %%
# сохранение модели и весов
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('сохранить обученную модель как %s ' % model_path)
# Out:
# сохранить обученную модель как /content/saved_models/keras_cifar10_trained_model.h5

# %%
# проверка работы обученной модели
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.0953 - accuracy: 0.6230
# Test loss: 1.0953420400619507
# Test accuracy: 0.6230000257492065

# %% [markdown]
# ### <span class="girk">Выводы:</span>
#  1. Простая смена функции активации с ```relu``` на ```tanh``` + снижение ```Dropout``` в 2 раза позволила увеличить ```accuracy``` на тестовой выборке с 0,5 до 0,55
#  2. Уменьшение размера партии c 128 до 64 (batch) уменьшает точность
#  3. Замена функции активации в последнем слое активации с ```softmax``` на иную будет снижать точность.
#  4. Помимо конфигурирования слоев необходимо тюнить Dropout под каждую конфигурацию: уменьшение Convolution в первом слое с (3, 3) на (2, 2) и (1, 1) вместе с увеличением Dropout-ов с 0,06 до 0,1 привело к росту точности модели до 0,62.

# %% [markdown]
# ### <span class="burk">Задание 2.</span>
# **Опишите в анализе, какие изменения необходимо было бы внести в получившуюся
# нейронную сеть, если бы ей нужно было работать не с cifar10, а с MNIST, CIFAR100 и
# IMAGENET.**

# %% [markdown]
# **Для MNIST:**
#  - Необходимо понизить количество входящих каналов до 2 (черный и белый)
#  - Увеличить количество слоёв
#  - Увеличить количество эпох
#  - Тюнинг Dropout-ов
#
# **Для CIFAR100:**
#  - Увеличить количество выходных классов до 100
#  - Возможно понадобится пересмотр архитектуры, так как в CIFAR100 классы объединены в суперклассы по 5. Таким образом сеть должна сначала отнести изображение к одному из 20 суперклассов, затем уже определять к какому из классов внутри суперкласса относится тестовое изображение.
#  - Свертки и ядра возможно останутся такими же как в текущей модели, однако понадобится увеличение количества слоёв/эпох.
#  - Тюнинг Dropout-ов
#
# **Для IMAGENET:**
#  - Для анализа сета скорее всего потребуется ансамбль нейросетей, т.к. датасет очень большой.
#  - Следует использовать подход сеть-внутри-сети
#  - Учитывая что классов большое количество следует ограничить выборку.
#  - Количество выходных классов нужно увеличить, также увеличить свертки/пулинги
#  - Также понадобится увеличение количества слоёв/эпох

# %% [markdown]
# ### <span class="mark">Разбор ДЗ 09.06.2022</span>

# %%
def seed_random(seed=123):
  # The below is necessary for starting Numpy generated random numbers
  # in a well-defined initial state.
  np.random.seed(123)

  # The below is necessary for starting core Python generated random numbers
  # in a well-defined state.
  python_random.seed(123)

  # The below set_seed() will make random number generation
  # in the TensorFlow backend have a well-defined initial state.
  # For further details, see:
  # https://www.tensorflow.org/api_docs/python/tf/random/set_seed
  tf.random.set_seed(1234)

# %%
# установка параметров нейросети
batch_size = 128
num_classes = 10
epochs = 25
data_augmentation = True
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

# %%
# разделение тренировочной и тестовой выборки
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'тренировочные примеры')
print(x_test.shape[0], 'тестовые примеры')

# преобразование матрицы чисел 0-9 в бинарную матрицу чисел 0-1
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 тренировочные примеры
# 10000 тестовые примеры

# %%
seed_random()
# конфигурирование слоев нейросети
model = Sequential()

# слои нейросети отвественные за свертку и max-pooling
model.add(Conv2D(64, (4, 4), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (2, 2), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.05))

model.add(Conv2D(512, (2, 2), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.05))

# полносвязные слои нейронной сети
model.add(Flatten())
model.add(Dense(2048))
model.add(Activation('relu'))
model.add(Dropout(0.05))\

model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.05))

model.add(Dense(512))
model.add(Activation('relu'))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
from gc import callbacks
def scheduler(epoch, lr):
  return lr * 0.5
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)


# инициализация Adam optimizer
opt = keras.optimizers.Adam(learning_rate=3e-4)

# компиляция модели
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
# запуск data augmentation через fit_generator
model.fit(datagen.flow(x_train, y_train,
                       batch_size=batch_size),
          epochs=epochs,
          validation_data=(x_test, y_test))
          # validation_data=(x_test, y_test), callbacks=[callback])
# Out:
# Epoch 1/25
# 391/391 [==============================] - 25s 61ms/step - loss: 1.6935 - accuracy: 0.3636 - val_loss: 1.6289 - val_accuracy: 0.4196
# Epoch 2/25
# 391/391 [==============================] - 24s 61ms/step - loss: 1.3112 - accuracy: 0.5217 - val_loss: 1.1286 - val_accuracy: 0.5902
# Epoch 3/25
# 391/391 [==============================] - 24s 61ms/step - loss: 1.1125 - accuracy: 0.5985 - val_loss: 1.0634 - val_accuracy: 0.6157
# Epoch 4/25
# 391/391 [==============================] - 24s 62ms/step - loss: 0.9922 - accuracy: 0.6460 - val_loss: 0.9574 - val_accuracy: 0.6695
# Epoch 5/25
# 391/391 [==============================] - 24s 61ms/step - loss: 0.8973 - accuracy: 0.6836 - val_loss: 0.8456 - val_accuracy: 0.7078
# Epoch 6/25
# 391/391 [==============================] - 24s 61ms/step - loss: 0.8255 - accuracy: 0.7090 - val_loss: 0.8099 - val_accuracy: 0.7108
# Epoch 7/25
# 391/391 [==============================] - 24s 60ms/step - loss: 0.7828 - accuracy: 0.7244 - val_loss: 0.7584 - val_accuracy: 0.7355
# Epoch 8/25
# 391/391 [==============================] - 24s 60ms/step - loss: 0.7302 - accuracy: 0.7433 - val_loss: 0.7307 - val_accuracy: 0.7484
# Epoch 9/25
# 391/391 [==============================] - 24s 61ms/step - loss: 0.6859 - accuracy: 0.7591 - val_loss: 0.6705 - val_accuracy: 0.7650
# Epoch 10/25
# 391/391 [==============================] - 24s 61ms/step - loss: 0.6552 - accuracy: 0.7712 - val_loss: 0.7038 - val_accuracy: 0.7575
# Epoch 11/25
# 391/391 [==============================] - 25s 63ms/step - loss: 0.6319 - accuracy: 0.7780 - val_loss: 0.6517 - val_accuracy: 0.7760
# Epoch 12/25
# 391/391 [==============================] - 24s 61ms/step - loss: 0.6014 - accuracy: 0.7877 - val_loss: 0.6190 - val_accuracy: 0.7849
# Epoch 13/25
# 391/391 [==============================] - 24s 60ms/step - loss: 0.5744 - accuracy: 0.7982 - val_loss: 0.5995 - val_accuracy: 0.7919
# Epoch 14/25
# 391/391 [==============================] - 24s 60ms/step - loss: 0.5521 - accuracy: 0.8056 - val_loss: 0.5908 - val_accuracy: 0.7962
# Epoch 15/25
# 391/391 [==============================] - 24s 61ms/step - loss: 0.5307 - accuracy: 0.8129 - val_loss: 0.6039 - val_accuracy: 0.7892
# Epoch 16/25
# 391/391 [==============================] - 24s 61ms/step - loss: 0.5038 - accuracy: 0.8213 - val_loss: 0.5727 - val_accuracy: 0.8019
# Epoch 17/25
# 391/391 [==============================] - 24s 61ms/step - loss: 0.4915 - accuracy: 0.8271 - val_loss: 0.5705 - val_accuracy: 0.8058
# Epoch 18/25
# 391/391 [==============================] - 24s 61ms/step - loss: 0.4705 - accuracy: 0.8365 - val_loss: 0.5869 - val_accuracy: 0.8014
# Epoch 19/25
# 391/391 [==============================] - 24s 63ms/step - loss: 0.4482 - accuracy: 0.8412 - val_loss: 0.5635 - val_accuracy: 0.8094
# Epoch 20/25
# 391/391 [==============================] - 24s 62ms/step - loss: 0.4348 - accuracy: 0.8456 - val_loss: 0.5540 - val_accuracy: 0.8135
# Epoch 21/25
# 391/391 [==============================] - 24s 60ms/step - loss: 0.4197 - accuracy: 0.8516 - val_loss: 0.5628 - val_accuracy: 0.8138
# Epoch 22/25
# 391/391 [==============================] - 24s 60ms/step - loss: 0.4009 - accuracy: 0.8577 - val_loss: 0.5580 - val_accuracy: 0.8139
# Epoch 23/25
# 391/391 [==============================] - 25s 63ms/step - loss: 0.3906 - accuracy: 0.8611 - val_loss: 0.5728 - val_accuracy: 0.8123
# Epoch 24/25
# 391/391 [==============================] - 23s 60ms/step - loss: 0.3720 - accuracy: 0.8673 - val_loss: 0.5920 - val_accuracy: 0.8115
# Epoch 25/25
# 391/391 [==============================] - 25s 63ms/step - loss: 0.3506 - accuracy: 0.8753 - val_loss: 0.5707 - val_accuracy: 0.8177

# %%
# сохранение модели и весов
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('сохранить обученную модель как %s ' % model_path)
# Out:
# сохранить обученную модель как /content/saved_models/keras_cifar10_trained_model.h5

# %%
# проверка работы обученной модели
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5707 - accuracy: 0.8177
# Test loss: 0.570744514465332
# Test accuracy: 0.8177000284194946

# %% [markdown]
# __*Комментарии преподавателя:*__<br>
# *Милена Сокол・Преподаватель<br>*
#
# Здравствуйте!
#
# Спасибо, отличное решение
